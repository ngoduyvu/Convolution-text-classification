# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from matplotlib import pylab

# %%
from load_data import load_file, separate_data_label

# %%
document = load_file("2007ChallengeTrainData.xml")
id_doc, label, words = separate_data_label(document)

# %%
print('Data size %d' % len(words))
# Out:
# Data size 1956

# %%
words = [item for sublist in words for item in sublist]

# %%
vocabulary_size = len(words)

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
vocabulary_size = len(reverse_dictionary)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 0], ('of', 784), ('with', 715), ('the', 700), ('and', 452)]
# Sample data [2058, 53, 6, 2, 959, 918, 1182, 993, 26, 768]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-447381f90115> in <module>()
#      25   return batch, labels
#      26
# ---> 27 print('data:', [reverse_dictionary[di] for di in data[:8]])
#      28
#      29 for num_skips, skip_window in [(2, 1), (4, 2)]:
#
# NameError: name 'data' is not defined

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0c56de3a0d2e> in <module>()
#       8 valid_size = 16 # Random set of words to evaluate similarity on.
#       9 valid_window = 100 # Only pick dev samples in the head of the distribution.
# ---> 10 valid_examples = np.array(random.sample(range(valid_window), valid_size))
#      11 num_sampled = 64 # Number of negative examples to sample.
#      12
#
# NameError: name 'np' is not defined

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):  
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 5.810109
# Nearest to social: delayed, modern, importance, overwhelming, espoused, itself, formet, lands,
# Nearest to anarcho: competition, regulating, hip, new, impossibility, conditions, helps, opportunities,
# Nearest to feminism: attention, environment, property, grubacic, cease, amoralism, red, listed,
# Nearest to movements: may, cure, revolutionist, international, heavily, experience, leader, zeno,
# Nearest to they: attempts, restricted, traditions, operation, skills, into, workplace, eight,
# Nearest to cnt: considerably, variant, amoralism, dynamics, bordering, nacional, food, setting,
# Nearest to he: obey, encountered, vulnerabilities, ground, abolition, capitalism, insurrectionary, jacque,
# Nearest to its: motion, way, words, particularly, worldview, move, caplan, under,
# Nearest to but: modes, will, base, popular, home, stirner, set, supplant,
# Nearest to post: mid, others, zinn, historian, fred, reemerged, conclude, reason,
# Nearest to was: organising, places, faction, destroying, provide, party, using, cause,
# Nearest to term: include, zapatista, rumors, sans, applying, zapatismo, themselves, carried,
# Nearest to many: occupation, cypherpunk, oxymoron, further, seen, intervene, hundred, carl,
# Nearest to society: price, roots, facade, form, away, embodying, alternatives, dielo,
# Nearest to also: obediance, front, bayonets, nechaev, posited, private, refers, need,
# Nearest to two: neither, capitalism, hurled, instead, overthrow, feminist, elimination, pacifist,
# Average loss at step 2000: 2.293935
# Average loss at step 4000: 1.550453
# Average loss at step 6000: 1.480318
# Average loss at step 8000: 1.447204
# Average loss at step 10000: 1.425312
# Nearest to social: delayed, combination, seminal, capable, marxist, itself, ireland, determining,
# Nearest to anarcho: regulating, impossibility, culottes, rise, competition, ecofeminism, n, resistance,
# Nearest to feminism: attention, environment, internationals, rique, grubacic, disappears, idea, wishes,
# Nearest to movements: leader, colonialism, reason, mental, civilization, labor, may, involved,
# Nearest to they: restricted, roles, attempts, skills, current, into, operation, louis,
# Nearest to cnt: legitimacy, considerably, region, setting, adopted, victorious, distinct, syndrome,
# Nearest to he: extensive, bonanno, communistic, ground, encountered, value, obey, vulnerabilities,
# Nearest to its: way, schooling, groups, wollstonecraft, metaphor, supported, worldview, nonviolent,
# Nearest to but: popular, will, modes, litist, communicate, be, supplant, striking,
# Nearest to post: mid, artist, historian, travail, magnitude, randolph, especially, zinn,
# Nearest to was: sectarianism, saw, places, organising, complex, catalonia, day, creation,
# Nearest to term: idea, sans, fight, zapatista, alternatives, applying, carried, include,
# Nearest to many: oxymoron, jan, k, seen, xu, moved, technological, human,
# Nearest to society: price, resulted, confines, estimate, strongly, interfering, argentina, central,
# Nearest to also: reemerged, obediance, equal, brief, abacus, originally, refers, though,
# Nearest to two: four, nine, th, vision, eight, six, zero, beneficial,
# Average loss at step 12000: 1.409157
# Average loss at step 14000: 1.396461
# Average loss at step 16000: 1.388049
# Average loss at step 18000: 1.378064
# Average loss at step 20000: 1.371765
# Nearest to social: combination, delayed, capable, mainstream, seminal, ireland, determining, amoralism,
# Nearest to anarcho: impossibility, baltimore, decades, black, unlike, city, interact, n,
# Nearest to feminism: attention, idea, environment, internationals, rique, movement, disappears, activity,
# Nearest to movements: leader, mental, reason, goals, labor, civilization, books, stanley,
# Nearest to they: roles, restricted, attempts, skills, exist, impossibility, current, colonialism,
# Nearest to cnt: adopted, region, legitimacy, setting, considerably, victorious, influenced, accumulated,
# Nearest to he: claim, value, bonanno, extensive, ecofeminism, clinical, ground, obey,
# Nearest to its: way, respect, wollstonecraft, metaphor, nonviolent, examples, entirely, choices,
# Nearest to but: communicate, popular, striking, will, opposes, be, relating, litist,
# Nearest to post: artist, mid, travail, especially, advocated, historian, including, zinn,
# Nearest to was: sectarianism, complex, saw, catalonia, worldwide, creation, places, votes,
# Nearest to term: idea, sans, fight, alternatives, zapatista, join, carried, satisfaction,
# Nearest to many: jan, oxymoron, k, human, moved, emma, technological, seen,
# Nearest to society: resulted, estimate, price, confines, desires, interfering, argentina, strongly,
# Nearest to also: though, reemerged, abacus, equal, originally, brief, found, refers,
# Nearest to two: four, nine, eight, th, vision, zero, six, seven,
# Average loss at step 22000: 1.368635
# Average loss at step 24000: 1.360212
# Average loss at step 26000: 1.355771
# Average loss at step 28000: 1.349586
# Average loss at step 30000: 1.348561
# Nearest to social: combination, capable, delayed, determining, mainstream, ireland, seminal, restricted,
# Nearest to anarcho: impossibility, decades, city, interact, incompatible, nihilist, grouped, establishment,
# Nearest to feminism: attention, idea, movement, inspired, internationals, environment, rique, motion,
# Nearest to movements: leader, reason, mental, goals, impossibility, books, crimethinc, civilization,
# Nearest to they: roles, restricted, exist, impossibility, attempts, movements, skills, relationships,
# Nearest to cnt: adopted, region, legitimacy, criticised, influenced, victorious, setting, considerably,
# Nearest to he: claim, value, ecofeminism, extensive, bonanno, occasionally, abolition, communistic,
# Nearest to its: way, respect, examples, figures, nonviolent, metaphor, supported, lead,
# Nearest to but: communicate, popular, striking, litist, create, want, fighting, relating,
# Nearest to post: artist, travail, market, mid, full, especially, advocated, magnitude,
# Nearest to was: sectarianism, saw, played, had, complex, worldwide, catalonia, creation,
# Nearest to term: idea, fight, sans, join, zapatista, alternatives, satisfaction, kind,
# Nearest to many: jan, oxymoron, moved, k, technological, ideology, human, seen,
# Nearest to society: estimate, resulted, desires, price, milestones, interfering, confines, argentina,
# Nearest to also: though, reemerged, abacus, brief, originally, small, found, equal,
# Nearest to two: four, nine, zero, seven, eight, th, vision, six,
# Average loss at step 32000: 1.340969
# Average loss at step 34000: 1.342268
# Average loss at step 36000: 1.342258
# Average loss at step 38000: 1.335482
# Average loss at step 40000: 1.331386
# Nearest to social: combination, capable, bleuler, delayed, ireland, restricted, mainstream, determining,
# Nearest to anarcho: black, city, impossibility, interact, establishment, decades, culottes, unlike,
# Nearest to feminism: attention, movement, idea, goldman, motion, inspired, rique, internationals,
# Nearest to movements: leader, impossibility, books, mental, goals, reason, civilization, they,
# Nearest to they: roles, restricted, exist, movements, revolutionist, colonialism, impossibility, relationships,
# Nearest to cnt: adopted, influenced, criticised, accumulated, region, strategy, legitimacy, until,
# Nearest to he: claim, value, ecofeminism, extensive, bonanno, economy, abolition, occasionally,
# Nearest to its: respect, way, examples, leader, metaphor, figures, your, entirely,
# Nearest to but: communicate, popular, want, striking, clearly, create, fighting, litist,
# Nearest to post: artist, especially, market, full, advocated, including, travail, criticizes,
# Nearest to was: sectarianism, saw, played, catalonia, worldwide, complex, opposition, is,
# Nearest to term: idea, fight, join, sans, alternatives, zapatista, certainly, kind,
# Nearest to many: jan, moved, oxymoron, ideology, technological, k, emma, violence,
# Nearest to society: resulted, estimate, desires, interfering, milestones, price, confines, argentina,
# Nearest to also: though, reemerged, abacus, small, brief, refers, originally, equal,
# Nearest to two: four, nine, seven, eight, th, vision, six, zero,
# Average loss at step 42000: 1.334207
# Average loss at step 44000: 1.330477
# Average loss at step 46000: 1.329307
# Average loss at step 48000: 1.324164
# Average loss at step 50000: 1.325795
# Nearest to social: combination, capable, mainstream, bleuler, delayed, restricted, ireland, determining,
# Nearest to anarcho: city, answers, interact, impossibility, black, incompatible, establishment, baltimore,
# Nearest to feminism: attention, movement, idea, inspired, goldman, motion, taken, fascism,
# Nearest to movements: leader, books, impossibility, goals, mental, they, reason, labor,
# Nearest to they: movements, exist, roles, restricted, relationships, revolutionist, impossibility, included,
# Nearest to cnt: adopted, criticised, region, accumulated, syndrome, label, legitimacy, strategy,
# Nearest to he: claim, ecofeminism, value, economy, bonanno, extensive, results, communist,
# Nearest to its: way, respect, examples, figures, nonviolent, thought, leader, metaphor,
# Nearest to but: communicate, popular, want, striking, create, clearly, fighting, decades,
# Nearest to post: especially, artist, criticizes, market, crypto, other, including, travail,
# Nearest to was: sectarianism, saw, played, worldwide, journal, complex, catalonia, is,
# Nearest to term: idea, fight, join, sans, kind, how, certainly, zapatista,
# Nearest to many: ideology, jan, moved, oxymoron, violence, technological, k, human,
# Nearest to society: resulted, estimate, interfering, desires, milestones, price, theoretical, similarities,
# Nearest to also: though, reemerged, abacus, small, brief, been, refers, found,
# Nearest to two: four, seven, nine, eight, six, zero, th, vision,
# Average loss at step 52000: 1.320711
# Average loss at step 54000: 1.318101
# Average loss at step 56000: 1.315029
# Average loss at step 58000: 1.318858
# Average loss at step 60000: 1.315762
# Nearest to social: combination, restricted, capable, bleuler, mainstream, ireland, satisfaction, amoralism,
# Nearest to anarcho: city, interact, establishment, answers, impossibility, delay, incompatible, culottes,
# Nearest to feminism: attention, movement, idea, goldman, inspired, motion, activity, taken,
# Nearest to movements: leader, books, impossibility, mental, goals, crimethinc, reason, they,
# Nearest to they: roles, exist, revolutionist, movements, relationships, impossibility, included, restricted,
# Nearest to cnt: adopted, criticised, region, strategy, influenced, old, accumulated, label,
# Nearest to he: claim, ecofeminism, value, they, results, economy, decentralized, extensive,
# Nearest to its: respect, way, examples, nonviolent, figures, thought, your, leader,
# Nearest to but: communicate, popular, want, create, relating, fighting, clearly, decades,
# Nearest to post: artist, especially, market, criticizes, involves, including, travail, striking,
# Nearest to was: sectarianism, worldwide, played, saw, catalonia, complex, explicitly, journal,
# Nearest to term: idea, fight, join, how, kind, way, certainly, sans,
# Nearest to many: ideology, jan, moved, violence, oxymoron, k, technological, human,
# Nearest to society: resulted, estimate, desires, milestones, interfering, theoretical, price, term,
# Nearest to also: though, reemerged, abacus, small, ideological, been, brief, refers,
# Nearest to two: four, seven, nine, eight, six, zero, th, vision,
# Average loss at step 62000: 1.310905
# Average loss at step 64000: 1.313168
# Average loss at step 66000: 1.317825
# Average loss at step 68000: 1.309960
# Average loss at step 70000: 1.309539
# Nearest to social: combination, bleuler, capable, restricted, political, mainstream, ireland, satisfaction,
# Nearest to anarcho: city, interact, establishment, impossibility, decades, answers, incompatible, culottes,
# Nearest to feminism: movement, goldman, attention, idea, inspired, taken, motion, symptoms,
# Nearest to movements: leader, books, impossibility, mental, goals, they, crimethinc, reason,
# Nearest to they: exist, roles, movements, relationships, individuals, impossibility, restricted, revolutionist,
# Nearest to cnt: adopted, criticised, accumulated, old, influenced, region, strategy, legitimacy,
# Nearest to he: claim, value, ecofeminism, economy, decentralized, results, bonanno, occasionally,
# Nearest to its: respect, way, examples, leader, thought, so, figures, had,
# Nearest to but: communicate, popular, want, create, fighting, clearly, decades, relating,
# Nearest to post: especially, artist, criticizes, market, conflict, other, striking, including,
# Nearest to was: sectarianism, worldwide, is, played, journal, complex, catalonia, saw,
# Nearest to term: idea, join, fight, certainly, how, kind, way, sans,
# Nearest to many: ideology, jan, violence, human, moved, k, technological, oxymoron,
# Nearest to society: estimate, resulted, desires, interfering, milestones, similarities, theoretical, price,
# Nearest to also: though, reemerged, abacus, small, brief, article, refers, found,
# Nearest to two: four, seven, six, eight, nine, th, vision, zero,
# Average loss at step 72000: 1.304374
# Average loss at step 74000: 1.306726
# Average loss at step 76000: 1.307226
# Average loss at step 78000: 1.301117
# Average loss at step 80000: 1.299895
# Nearest to social: restricted, combination, capable, develops, political, bleuler, amoralism, ireland,
# Nearest to anarcho: city, interact, establishment, impossibility, culottes, degree, decades, delay,
# Nearest to feminism: goldman, movement, attention, idea, motion, inspired, so, activity,
# Nearest to movements: books, leader, impossibility, mental, goals, labor, psychology, relations,
# Nearest to they: exist, revolutionist, included, roles, individuals, relationships, impossibility, movements,
# Nearest to cnt: adopted, criticised, influenced, accumulated, label, region, strategy, old,
# Nearest to he: claim, ecofeminism, value, economy, they, decentralized, results, bonanno,
# Nearest to its: respect, examples, thought, so, nonviolent, leader, figures, way,
# Nearest to but: communicate, popular, want, clearly, fighting, create, decades, rose,
# Nearest to post: especially, criticizes, insurrectionary, including, crypto, artist, market, conflict,
# Nearest to was: sectarianism, early, saw, complex, played, worldwide, is, catalonia,
# Nearest to term: idea, join, fight, way, how, kind, certainly, satisfaction,
# Nearest to many: ideology, jan, moved, violence, human, history, technological, oxymoron,
# Nearest to society: resulted, estimate, desires, interfering, theoretical, milestones, price, similarities,
# Nearest to also: though, abacus, reemerged, small, brief, sometimes, left, ideological,
# Nearest to two: four, seven, six, nine, eight, zero, th, vision,
# Average loss at step 82000: 1.305219
# Average loss at step 84000: 1.303148
# Average loss at step 86000: 1.297569
# Average loss at step 88000: 1.301857
# Average loss at step 90000: 1.301220
# Nearest to social: combination, restricted, amoralism, capable, mainstream, bleuler, ireland, satisfaction,
# Nearest to anarcho: city, interact, impossibility, establishment, decades, culottes, unlike, answers,
# Nearest to feminism: movement, attention, idea, inspired, motion, goldman, activity, fascism,
# Nearest to movements: books, leader, impossibility, mental, goals, crimethinc, psychology, labor,
# Nearest to they: individuals, roles, exist, revolutionist, relationships, impossibility, movements, included,
# Nearest to cnt: adopted, criticised, old, label, accumulated, region, strategy, subject,
# Nearest to he: claim, ecofeminism, value, decentralized, economy, they, results, disagreement,
# Nearest to its: respect, examples, thought, way, nonviolent, so, leader, philosophies,
# Nearest to but: communicate, popular, want, clearly, create, fighting, relating, striking,
# Nearest to post: criticizes, especially, including, insurrectionary, crypto, artist, other, conflict,
# Nearest to was: sectarianism, played, is, journal, worldwide, freetown, hundred, complex,
# Nearest to term: idea, join, fight, way, how, certainly, right, kind,
# Nearest to many: ideology, jan, moved, technological, emma, violence, human, k,
# Nearest to society: resulted, estimate, desires, similarities, theoretical, interfering, milestones, group,
# Nearest to also: though, reemerged, abacus, small, sometimes, ideological, brief, left,
# Nearest to two: four, seven, nine, eight, six, th, five, zero,
# Average loss at step 92000: 1.296874
# Average loss at step 94000: 1.297555
# Average loss at step 96000: 1.294209
# Average loss at step 98000: 1.295651
# Average loss at step 100000: 1.295859
# Nearest to social: capable, combination, restricted, amoralism, bleuler, ireland, satisfaction, mainstream,
# Nearest to anarcho: city, interact, establishment, delay, incompatible, developing, impossibility, culottes,
# Nearest to feminism: goldman, movement, attention, inspired, idea, motion, taken, activity,
# Nearest to movements: leader, books, impossibility, crimethinc, mental, they, psychology, goals,
# Nearest to they: individuals, exist, movements, roles, relationships, impossibility, revolutionist, explicitly,
# Nearest to cnt: adopted, criticised, strategy, label, old, subject, syndrome, accumulated,
# Nearest to he: claim, ecofeminism, value, decentralized, results, disagreement, economy, occasionally,
# Nearest to its: respect, examples, so, leader, thought, way, figures, nonviolent,
# Nearest to but: communicate, popular, want, clearly, fighting, create, opposition, relation,
# Nearest to post: criticizes, insurrectionary, crypto, especially, including, other, conflict, artist,
# Nearest to was: sectarianism, played, is, when, early, explicitly, worldwide, journal,
# Nearest to term: idea, join, fight, certainly, how, way, right, kind,
# Nearest to many: ideology, violence, moved, jan, human, k, technological, history,
# Nearest to society: resulted, estimate, theoretical, interfering, desires, similarities, milestones, historical,
# Nearest to also: though, abacus, reemerged, small, left, ideological, sometimes, been,
# Nearest to two: four, seven, nine, six, zero, eight, th, five,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
