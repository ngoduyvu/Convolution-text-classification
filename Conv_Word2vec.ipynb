# %% [markdown]
# ### Import Library and function

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import sklearn as sk
import pandas
import numpy as np
import tensorflow as tf
import random
import os
import collections
import math
import time
import datetime
from tensorflow.contrib import learn
from sklearn import metrics
from sklearn.manifold import TSNE
from sklearn.cross_validation import train_test_split
from matplotlib import pylab, pyplot

# Allow print picture or graph in Ipython
# %matplotlib inline
# Allow print all arry if command print called
np.set_printoptions(threshold=np.inf)

# %%
from load_data import load_file, separate_data_label, label_encoding

# %%
from text_cnn import TextCNN

# %% [markdown]
# ### Loading Dataset

# %%
# Load classified Document
document1 = load_file("2007ChallengeTrainData.xml")
id_doc1, labels, words1 = separate_data_label(document1)

# %%
# Load unclassified Document
# Load more words from these document to improve word-embedding
document2 = load_file("2007ChallengeTestDataNoCodes.xml")
id_doc2, labels2, words2 = separate_data_label(document2)            # labels2 is empty variable

# %%
# Joint all the data together
id_doc = id_doc1 + id_doc2
words = words1 + words2

# %%
# Convert multidimension array into 1D array
words = [index.split() for index in words]                           # Separate words in sentences
words = [item for sublist in words for item in sublist]              # Turn multidimension list into 1D list

# %% [markdown]
# ### Pre-training Word2vec

# %%
vocabulary_size = len(words)

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  #print(count)
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

# reverse_dictionary used number index to access
# dictionary used word keyword to access
data, count, dictionary, reverse_dictionary = build_dataset(words)

del words  # Hint to reduce memory.
#add this line to modify
vocabulary_size = len(dictionary)
print('Dictionary size', len(dictionary))
# Out:
# Dictionary size 2000

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):  
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 5.747293
# Nearest to study: superimposition, room, visible, waxing, some, calyceal, spleen, via,
# Nearest to wheezing: process, was, physical, keeping, lining, donor, cyst, would,
# Nearest to evidence: denise, urothelial, osteosarcoma, nodule, intraluminal, operation, held, night,
# Nearest to with: proteinuria, thought, symptomatology, ago, pregnancy, existing, positive, measuring,
# Nearest to lobe: opacity, impression, nonobstructive, trained, marked, thirteen, just, radiating,
# Nearest to lower: count, round, notified, pneumonias, anatomic, perinephric, caused, features,
# Nearest to 4: tubes, workup, cf, analysis, do, scar, diaphragmatic, 100,
# Nearest to 's: worse, account, fatigue, bibasilar, superior, brain, final, intrauterine,
# Nearest to prior: thoracic, newborn, characteristics, decubitus, component, approximate, artery, line,
# Nearest to disease: old, lobulated, earlier, follow, recent, show, effects, micturition,
# Nearest to small: 100, anniversary, l, thoracolumbar, minimal, technique, signifying, continues,
# Nearest to 1: basketball, please, nephrolithiasis, sickle, tracheomalacia, costochondral, demonstrating, base,
# Nearest to bilateral: tonsils, 0, multicystic, illness, symptomatology, crowding, noncomplicated, clips,
# Nearest to focal: cells, interventional, had, retroperitoneal, pyelectasis, must, by, suspicious,
# Nearest to status: consequence, fistula, fold, infections, entirely, structure, nocturnal, so,
# Nearest to 7: they, initial, document, size, towards, workup, straight, urge,
# Average loss at step 2000: 2.829221
# Average loss at step 4000: 2.333361
# Average loss at step 6000: 2.195636
# Average loss at step 8000: 2.117019
# Average loss at step 10000: 2.069644
# Nearest to study: examination, ultrasound, radiograph, superimposition, dysfunction, exam, relieved, bifida,
# Nearest to wheezing: cough, physical, process, congested, airways, overall, proximity, deviations,
# Nearest to evidence: denise, focal, osteosarcoma, operation, urothelial, intraluminal, definable, nodule,
# Nearest to with: radiopaque, \), calix, when, pregnancy, artificial, impression, symptomatology,
# Nearest to lobe: finding, can, superimposed, trained, bronchitis, parent, caused, yesterday,
# Nearest to lower: upper, posterior, count, features, pneumonias, perinephric, round, mild,
# Nearest to 4: 2, 3, 6, 7, 8, six, 12, tubes,
# Nearest to 's: fatigue, worse, account, lingual, x5, vertebral, improving, region,
# Nearest to prior: characteristics, duplications, thoracic, four, including, stage, single, intrathoracic,
# Nearest to disease: show, septation, assuming, athens, calix, body, opacities, etiology,
# Nearest to small: anniversary, large, bacterial, significant, utero, subtle, shadowing, minimal,
# Nearest to 1: 14, fourchette, nodes, measures, 26, impressed, lumen, component,
# Nearest to bilateral: hemithorax, left, lobulation, croupy, discoid, lesion, 01, confluence,
# Nearest to focal: cells, superimposed, evidence, definite, support, acute, patchy, interventional,
# Nearest to status: fold, hemorrhage, whether, consequence, into, 29, radiopaque, zithromax,
# Nearest to 7: 6, 9, 8, 4, 10, 5, 12, lymphadenopathy,
# Average loss at step 12000: 2.037328
# Average loss at step 14000: 2.008569
# Average loss at step 16000: 1.993814
# Average loss at step 18000: 1.985872
# Average loss at step 20000: 1.982306
# Nearest to study: examination, ultrasound, exam, radiograph, superimposition, dysfunction, pyeloplasty, pneumothorax,
# Nearest to wheezing: cough, physical, process, congested, days, fever, perihilar, male,
# Nearest to evidence: denise, focal, passage, definable, true, operation, intraluminal, normal,
# Nearest to with: calix, radiopaque, whose, and, \), symptomatology, when, x4,
# Nearest to lobe: medial, segment, frank, bronchitis, effect, focal, superimposed, pole,
# Nearest to lower: upper, posterior, mid, anterior, tubes, lateral, features, reanastomosis,
# Nearest to 4: 2, 7, 3, 6, 8, six, five, 5,
# Nearest to 's: fatigue, lingual, x5, vertebral, has, account, inflammatory, sized,
# Nearest to prior: characteristics, last, january, duplications, four, hematuria, previous, coughing,
# Nearest to disease: show, septation, athens, assuming, can, arch, fibrosis, opacities,
# Nearest to small: utero, large, anniversary, shadowing, bacterial, more, splinting, wedge,
# Nearest to 1: 14, lumen, enlarged, impressed, 26, component, fourchette, measures,
# Nearest to bilateral: hemithorax, left, sided, lobulation, ii, discoid, lesion, analysis,
# Nearest to focal: superimposed, lobar, definite, evidence, acute, cells, support, patchy,
# Nearest to status: fold, hemorrhage, whether, 29, tube, zithromax, normalize, radiopaque,
# Nearest to 7: 6, 9, 4, 10, 8, thirteen, 5, 21,
# Average loss at step 22000: 1.971649
# Average loss at step 24000: 1.959932
# Average loss at step 26000: 1.954875
# Average loss at step 28000: 1.952856
# Average loss at step 30000: 1.949135
# Nearest to study: examination, exam, ultrasound, radiograph, histoplasma, bifida, pyeloplasty, pneumothorax,
# Nearest to wheezing: cough, fever, days, perihilar, process, congested, male, increased,
# Nearest to evidence: denise, focal, features, true, passage, normal, definable, pneumothorax,
# Nearest to with: calix, \), radiopaque, whose, prolonged, margin, without, artificial,
# Nearest to lobe: medial, segment, bronchitis, icd, focal, suprahilar, space, cells,
# Nearest to lower: upper, posterior, tubes, mid, lateral, anterior, arm, rales,
# Nearest to 4: 7, 6, 8, 2, 3, 5, five, six,
# Nearest to 's: fatigue, has, vertebral, inflammatory, lingual, x5, region, account,
# Nearest to prior: characteristics, last, previous, duplications, january, four, half, including,
# Nearest to disease: septation, assuming, show, athens, fibrosis, calix, can, arch,
# Nearest to small: utero, shadowing, more, large, nondilated, wedge, anniversary, splinting,
# Nearest to 1: impressed, 14, component, fourchette, progressed, 26, measures, lumen,
# Nearest to bilateral: lobulation, left, hemithorax, sided, discoid, analysis, lesion, dysuria,
# Nearest to focal: definite, lobar, superimposed, evidence, cells, patchy, acute, support,
# Nearest to status: fold, whether, hemorrhage, tube, 29, zithromax, growing, radiopaque,
# Nearest to 7: 9, 6, 4, 8, 10, 5, car, 16,
# Average loss at step 32000: 1.947014
# Average loss at step 34000: 1.944496
# Average loss at step 36000: 1.939971
# Average loss at step 38000: 1.927695
# Average loss at step 40000: 1.933008
# Nearest to study: examination, exam, ultrasound, radiograph, ast, demonstrating, physiologic, histoplasma,
# Nearest to wheezing: cough, fever, days, male, perihilar, congested, process, acute,
# Nearest to evidence: focal, features, true, denise, pneumothorax, passage, tb, empyema,
# Nearest to with: calix, radiopaque, x4, whose, \), artificial, without, when,
# Nearest to lobe: medial, focal, icd, segment, suprahilar, cells, row, bronchitis,
# Nearest to lower: upper, tubes, posterior, anterior, mid, lateral, inferior, mild,
# Nearest to 4: 7, 2, 6, 8, 3, five, six, cf,
# Nearest to 's: fatigue, vertebral, has, inflammatory, asymmetrically, x5, reports, positioned,
# Nearest to prior: last, characteristics, previous, january, half, duplications, same, coughing,
# Nearest to disease: fibrosis, septation, show, radiograph, assuming, pneumonia, arch, can,
# Nearest to small: utero, shadowing, more, large, reactive, wedging, nondilated, splinting,
# Nearest to 1: component, x1, impressed, progressed, measures, fourchette, enlarged, lumen,
# Nearest to bilateral: left, lobulation, sided, hemithorax, analysis, ii, discoid, clinic,
# Nearest to focal: lobar, definite, evidence, superimposed, acute, bacterial, space, lobe,
# Nearest to status: tube, fold, hemorrhage, whether, growing, 29, radiopaque, acquired,
# Nearest to 7: 9, 6, 4, 10, 8, 16, car, 15,
# Average loss at step 42000: 1.933476
# Average loss at step 44000: 1.931954
# Average loss at step 46000: 1.926590
# Average loss at step 48000: 1.920010
# Average loss at step 50000: 1.923755
# Nearest to study: examination, exam, ultrasound, demonstrating, histoplasma, gastrocystoplasty, ast, made,
# Nearest to wheezing: cough, days, fever, male, perihilar, sore, disappearance, potty,
# Nearest to evidence: focal, features, true, pneumothorax, denise, appearance, fracture, tb,
# Nearest to with: calix, whose, and, track, artificial, falling, for, radiopaque,
# Nearest to lobe: medial, icd, effect, focal, segment, cells, suprahilar, lobes,
# Nearest to lower: upper, tubes, lateral, middle, mid, posterior, anterior, arm,
# Nearest to 4: 7, 8, 6, 2, 3, five, v, six,
# Nearest to 's: vertebral, asymmetrically, fatigue, x5, has, inflammatory, positioned, reports,
# Nearest to prior: last, characteristics, previous, january, reported, duplications, same, half,
# Nearest to disease: septation, show, radiograph, arch, assuming, fibrosis, athens, mm,
# Nearest to small: more, utero, shadowing, large, hugely, wedging, reactive, solitary,
# Nearest to 1: x1, component, impressed, 26, 3, progressed, slow, measures,
# Nearest to bilateral: left, lobulation, sided, ii, analysis, discoid, hemithorax, dysuria,
# Nearest to focal: lobar, definite, evidence, superimposed, acute, bacterial, patchy, space,
# Nearest to status: fold, whether, tube, growing, hemorrhage, 29, zithromax, acquired,
# Nearest to 7: 9, 4, 6, 8, 10, car, 5, 16,
# Average loss at step 52000: 1.924558
# Average loss at step 54000: 1.921541
# Average loss at step 56000: 1.919736
# Average loss at step 58000: 1.919649
# Average loss at step 60000: 1.913284
# Nearest to study: examination, exam, ultrasound, demonstrating, ast, histoplasma, physiologic, made,
# Nearest to wheezing: cough, fever, days, male, perihilar, sore, potty, acute,
# Nearest to evidence: focal, features, pneumothorax, true, signs, abnormality, fracture, empyema,
# Nearest to with: whose, calix, artificial, \), without, radiopaque, margin, and,
# Nearest to lobe: medial, icd, row, cells, focal, suprahilar, lobes, effect,
# Nearest to lower: upper, tubes, posterior, mid, middle, lateral, anterior, linear,
# Nearest to 4: 7, 8, 6, 2, 3, five, v, six,
# Nearest to 's: asymmetrically, vertebral, inflammatory, has, x5, fatigue, positioned, reports,
# Nearest to prior: last, characteristics, previous, half, january, reported, same, duplications,
# Nearest to disease: fibrosis, radiograph, arch, community, athens, assuming, mm, septation,
# Nearest to small: utero, more, shadowing, large, hugely, wedging, chronological, nondilated,
# Nearest to 1: component, impressed, x1, progressed, 26, slow, 3, fourchette,
# Nearest to bilateral: left, sided, lobulation, discoid, ii, analysis, central, clinic,
# Nearest to focal: evidence, definite, lobar, superimposed, acute, bacterial, space, calyx,
# Nearest to status: whether, tube, fold, acquired, growing, so, zithromax, hemorrhage,
# Nearest to 7: 9, 4, 6, 10, 8, car, 5, 16,
# Average loss at step 62000: 1.914922
# Average loss at step 64000: 1.915539
# Average loss at step 66000: 1.914697
# Average loss at step 68000: 1.910515
# Average loss at step 70000: 1.908822
# Nearest to study: examination, exam, ultrasound, demonstrating, ast, histoplasma, image, detected,
# Nearest to wheezing: cough, days, fever, male, sore, girl, acute, perihilar,
# Nearest to evidence: focal, features, pneumothorax, true, signs, fracture, appearance, empyema,
# Nearest to with: calix, whose, falling, and, artificial, margin, who, coffee,
# Nearest to lobe: medial, icd, focal, cells, row, lobes, effect, segment,
# Nearest to lower: upper, tubes, mid, anterior, lateral, middle, posterior, arm,
# Nearest to 4: 7, 6, 8, 2, 3, five, v, 13,
# Nearest to 's: asymmetrically, vertebral, fatigue, x5, has, positioned, up, inflammatory,
# Nearest to prior: last, previous, characteristics, same, half, reported, january, empyema,
# Nearest to disease: radiograph, arch, assuming, community, process, mm, plus, calix,
# Nearest to small: more, hugely, utero, shadowing, large, reactive, chronological, tiny,
# Nearest to 1: x1, component, impressed, 26, measures, lumen, 3, progressed,
# Nearest to bilateral: left, sided, lobulation, analysis, hemithorax, ii, central, discoid,
# Nearest to focal: lobar, definite, evidence, superimposed, bacterial, acute, patchy, support,
# Nearest to status: tube, whether, fold, growing, acquired, zithromax, partial, nine,
# Nearest to 7: 4, 9, 6, 10, 8, car, 5, 16,
# Average loss at step 72000: 1.902164
# Average loss at step 74000: 1.906638
# Average loss at step 76000: 1.913399
# Average loss at step 78000: 1.907476
# Average loss at step 80000: 1.908393
# Nearest to study: examination, exam, ultrasound, demonstrating, ast, histoplasma, detected, image,
# Nearest to wheezing: cough, fever, days, male, infections, sore, potty, girl,
# Nearest to evidence: features, focal, pneumothorax, appearance, signs, true, fracture, abnormality,
# Nearest to with: calix, artificial, whose, when, and, functional, coffee, margin,
# Nearest to lobe: medial, focal, icd, row, cells, lobes, suprahilar, noisy,
# Nearest to lower: upper, tubes, mid, lateral, anterior, posterior, arm, middle,
# Nearest to 4: 7, 8, 6, 2, five, 3, v, cf,
# Nearest to 's: asymmetrically, fatigue, positioned, vertebral, up, has, x5, inflammatory,
# Nearest to prior: last, previous, characteristics, half, reported, same, dictation, screening,
# Nearest to disease: fibrosis, radiograph, septation, assuming, process, calix, athens, mm,
# Nearest to small: more, utero, large, hugely, shadowing, chronological, solitary, wedging,
# Nearest to 1: component, impressed, x1, 26, 3, progressed, initial, fourchette,
# Nearest to bilateral: left, sided, lobulation, discoid, analysis, ii, column, clinic,
# Nearest to focal: lobar, definite, evidence, superimposed, acute, space, bacterial, lobe,
# Nearest to status: acquired, whether, tube, growing, fold, so, partial, poles,
# Nearest to 7: 4, 9, 6, 8, 10, car, 15, 5,
# Average loss at step 82000: 1.901807
# Average loss at step 84000: 1.898518
# Average loss at step 86000: 1.902095
# Average loss at step 88000: 1.904044
# Average loss at step 90000: 1.903881
# Nearest to study: examination, exam, ultrasound, demonstrating, ast, histoplasma, poor, image,
# Nearest to wheezing: cough, days, fever, male, sore, girl, acute, potty,
# Nearest to evidence: focal, features, pneumothorax, signs, appearance, fracture, true, tb,
# Nearest to with: calix, whose, artificial, who, functional, and, when, falling,
# Nearest to lobe: medial, icd, cells, focal, row, segment, worsening, noisy,
# Nearest to lower: upper, tubes, mid, lateral, anterior, middle, arm, posterior,
# Nearest to 4: 2, 7, 8, 6, five, 3, v, urinalysis,
# Nearest to 's: asymmetrically, vertebral, has, up, inflammatory, fatigue, positioned, lucent,
# Nearest to prior: last, previous, half, characteristics, same, january, reported, screening,
# Nearest to disease: fibrosis, process, radiograph, calix, septation, mm, community, arch,
# Nearest to small: more, utero, large, shadowing, hugely, chronological, reactive, solitary,
# Nearest to 1: component, x1, impressed, 3, 26, slow, progressed, repaired,
# Nearest to bilateral: sided, left, lobulation, ii, discoid, clinic, analysis, central,
# Nearest to focal: lobar, definite, evidence, acute, superimposed, bacterial, patchy, bony,
# Nearest to status: tube, acquired, growing, whether, fold, so, poles, partial,
# Nearest to 7: 9, 6, 4, 10, 8, car, 15, 16,
# Average loss at step 92000: 1.901298
# Average loss at step 94000: 1.895888
# Average loss at step 96000: 1.896402
# Average loss at step 98000: 1.900154
# Average loss at step 100000: 1.898749
# Nearest to study: examination, exam, ultrasound, demonstrating, histoplasma, ast, detected, image,
# Nearest to wheezing: cough, fever, days, male, girl, acute, infections, potty,
# Nearest to evidence: focal, features, signs, pneumothorax, fracture, abnormality, appearance, true,
# Nearest to with: calix, artificial, functional, when, whose, margin, few, who,
# Nearest to lobe: medial, icd, lobes, cells, focal, row, effect, noisy,
# Nearest to lower: upper, mid, tubes, lateral, anterior, arm, middle, posterior,
# Nearest to 4: 7, 8, 6, 2, five, 3, half, 10,
# Nearest to 's: asymmetrically, up, vertebral, explain, inflammatory, positioned, fatigue, mom,
# Nearest to prior: last, previous, half, reported, characteristics, same, up, dictation,
# Nearest to disease: fibrosis, athens, radiograph, calix, process, mm, septation, arch,
# Nearest to small: more, large, hugely, utero, shadowing, chronological, moderate, deflux,
# Nearest to 1: component, impressed, x1, 3, 26, progressed, marked, interval,
# Nearest to bilateral: left, lobulation, sided, analysis, column, discoid, ii, clinic,
# Nearest to focal: evidence, lobar, definite, superimposed, acute, bacterial, space, bony,
# Nearest to status: tube, whether, acquired, growing, so, partial, poles, nine,
# Nearest to 7: 4, 9, 6, 10, 8, car, 5, 15,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# ### Training

# %% [markdown]
# ##### Declare Parameter and Variable

# %%
embedding_dim = 128
filter_sizes = [3, 4, 5]
num_filters = 128
dropout_keep_prob = 0.5
l2_reg_lambda = 0.0

# %%
batch_size = 64
num_epochs = 200
evaluate_every = 50
checkpoint_every = 100

# %%
## find the maximum length of sentences could have
max_length = (max(len(index.split()) for index in words1))

# %%
# Create a 2D blank 2D array input
## array sentence temporary store Embedding vector for each sentence
array_sentence = np.zeros((max_length, embedding_size),dtype="float32")
## input x for neural network
x = np.zeros((len(words1),max_length*embedding_size),dtype="float32")

# %%
# One-hot-encoding label of each document
## Encode data Label in DataFrame type
y = label_encoding(labels, False)                                      # False for single label, True for multi-label
## Convert DataFrame type to numpy array for other calculation
y = y.as_matrix()

# %%
## separate sentence into words
words1 = [index.split() for index in words1]

# %%
counter = 0
counter_sentence = 0
for indexDoc in words1:
    for indexWord in indexDoc:
        if indexWord in dictionary:                             # Check If the words have in dictionary
            vectLocate = dictionary[indexWord]                  # All rare words is treated as UNK Token 
        else:
            vectLocate = dictionary['UNK']                      # If word is not in dictionary, It is the rare words            
        array_sentence[counter_sentence] = final_embeddings[vectLocate]            
        counter_sentence+= 1
        
    counter_sentence = 0           
    x[counter] = array_sentence.flatten()        
    counter+=1 

del array_sentence

# %% [markdown]
# ##### Prepare for Training Data and Test Data

# %%
# Randomly shuffle data
np.random.seed(10)
shuffle_indices = np.random.permutation(np.arange(len(y)))
x_shuffled = x[shuffle_indices]
y_shuffled = y[shuffle_indices]

# %%
# Split train/test set
# TODO: This is very crude, should use cross-validation
x_train, x_dev = x_shuffled[:-500], x_shuffled[-500:]
y_train, y_dev = y_shuffled[:-500], y_shuffled[-500:]

# %%
# Sort each data and label into one pair
# then shuffle to ensure randomness 
def batch_iter(data, batch_size, num_epochs, shuffle=True):
    """
    Generates a batch iterator for a dataset.
    """
    data = np.array(data)
    data_size = len(data)
    num_batches_per_epoch = int(len(data)/batch_size) + 1
    for epoch in range(num_epochs):
        # Shuffle the data at each epoch
        if shuffle:
            shuffle_indices = np.random.permutation(np.arange(data_size))
            shuffled_data = data[shuffle_indices]
        else:
            shuffled_data = data
        for batch_num in range(num_batches_per_epoch):
            start_index = batch_num * batch_size
            end_index = min((batch_num + 1) * batch_size, data_size)
            yield shuffled_data[start_index:end_index]

# %%
batches = batch_iter(
        list(zip(x_train, y_train)), batch_size, num_epochs)

# %% [markdown]
# ##### Prepare For The Neural Network and Training

# %%
## Arrays to stores training results
step_store = []
accuracy_store = []
eval_step = []
eval_accuracy = []
eval_loss = []
eval_precision = []
eval_recall = []
eval_f1 = []

# %%
def train_step(x_batch, y_batch):
    """
    A single training step
    """
    feed_dict = {
        cnn.input_x: x_batch,
        cnn.input_y: y_batch,
        cnn.dropout_keep_prob: dropout_keep_prob
    }
    _, step, summaries, loss, accuracy = sess.run(
        [train_op, global_step, train_summary_op, cnn.loss, cnn.accuracy],
        feed_dict)
    step_store.append(step)
    accuracy_store.append(accuracy)
    print("step {}, loss {:g}, acc {:g}".format(step, loss, accuracy))
    train_summary_writer.add_summary(summaries, step)

# %%
def dev_step(x_batch, y_batch, writer=None):
    """
    Evaluates model on a dev set
    """
    feed_dict = {
        cnn.input_x: x_batch,
        cnn.input_y: y_batch,
        cnn.dropout_keep_prob: 1.0
    }
    step, summaries, loss, accuracy, y_p = sess.run(
        [global_step, dev_summary_op, cnn.loss, cnn.accuracy, cnn.y_p],
        feed_dict)
    eval_step.append(step)
    eval_accuracy.append(accuracy)
    eval_loss.append(loss)
    y_true = np.argmax(y_dev,1)
    precision = sk.metrics.precision_score(y_true, y_p)
    recall = sk.metrics.recall_score(y_true, y_p)
    f1_score = sk.metrics.f1_score(y_true, y_p)
    eval_precision.append(precision)
    eval_recall.append(recall)
    eval_f1.append(f1_score)
    print("step {}, loss {:g}, acc {:g}, precison {}, recall {}, f1_score {}.".format(step, loss, accuracy, precision, recall, f1_score))

# %%
# Training
# ==================================================
with tf.Graph().as_default():
    session_conf = tf.ConfigProto(
      allow_soft_placement=True,
      log_device_placement=False)
    sess = tf.Session(config=session_conf)
    with sess.as_default():
        cnn = TextCNN(
            sequence_length=x_train.shape[1],
            num_classes=len(y[0]),
            vocab_size=len(dictionary),
            embedding_size=embedding_dim,
            filter_sizes=filter_sizes,
            num_filters=num_filters,
            l2_reg_lambda=l2_reg_lambda)

        # Define Training procedure
        global_step = tf.Variable(0, name="global_step", trainable=False)
        optimizer = tf.train.AdamOptimizer(1e-3)
        grads_and_vars = optimizer.compute_gradients(cnn.loss)
        train_op = optimizer.apply_gradients(grads_and_vars, global_step=global_step)

        # Keep track of gradient values and sparsity (optional)
        grad_summaries = []
        for g, v in grads_and_vars:
            if g is not None:
                grad_hist_summary = tf.histogram_summary("{}/grad/hist".format(v.name), g)
                sparsity_summary = tf.scalar_summary("{}/grad/sparsity".format(v.name), tf.nn.zero_fraction(g))
                grad_summaries.append(grad_hist_summary)
                grad_summaries.append(sparsity_summary)
        grad_summaries_merged = tf.merge_summary(grad_summaries)

        # Output directory for models and summaries
        timestamp = str(int(time.time()))
        out_dir = os.path.abspath(os.path.join(os.path.curdir, "runs", timestamp))
        print("Writing to {}\n".format(out_dir))

        # Summaries for loss and accuracy
        loss_summary = tf.scalar_summary("loss", cnn.loss)
        acc_summary = tf.scalar_summary("accuracy", cnn.accuracy)

        # Train Summaries
        train_summary_op = tf.merge_summary([loss_summary, acc_summary, grad_summaries_merged])
        train_summary_dir = os.path.join(out_dir, "summaries", "train")
        train_summary_writer = tf.train.SummaryWriter(train_summary_dir, sess.graph)

        # Dev summaries
        dev_summary_op = tf.merge_summary([loss_summary, acc_summary])
        dev_summary_dir = os.path.join(out_dir, "summaries", "dev")
        dev_summary_writer = tf.train.SummaryWriter(dev_summary_dir, sess.graph)

        # Checkpoint directory. Tensorflow assumes this directory already exists so we need to create it
        checkpoint_dir = os.path.abspath(os.path.join(out_dir, "checkpoints"))
        checkpoint_prefix = os.path.join(checkpoint_dir, "model")
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)
        saver = tf.train.Saver(tf.all_variables())

        # Store vocabulary embedded
        #dictionary.save(os.path.join(out_dir, "vocab"))

        # Initialize all variables
        sess.run(tf.initialize_all_variables())
# Out:
# Writing to /home/ubuntu/workspace/tensorflow/thesis/Real/runs/1475451288

# %%
# Evaluating
# ==================================================
start_time = time.time()
for batch in batches:
    x_batch, y_batch = zip(*batch)
    train_step(x_batch, y_batch)
    current_step = tf.train.global_step(sess, global_step)
    if current_step % evaluate_every == 0:
        print("\nEvaluation:")
        dev_step(x_dev, y_dev, writer=dev_summary_writer)
        print("")
        
time_exc = time.time() - start_time

# %%
pyplot.plot(step_store,accuracy_store,'b.')
pyplot.plot(eval_step,eval_accuracy,'r*')
pyplot.xlim(min(step_store)-0.1,max(step_store)+0.1)
pyplot.ylim(min(accuracy_store)-0.1,max(accuracy_store)+0.1)
pyplot.xlabel("Step")
pyplot.ylabel("Accuracy")
pyplot.title("Training and Testing Data")
pyplot.show()

# %%
pyplot.plot(eval_step,eval_f1,marker='*', color='g',label='f1 scores')
pyplot.xlabel('Step')
pyplot.title('F-test')
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(eval_step,eval_loss,label='loss')
pyplot.plot(eval_step,eval_accuracy,marker='o', linestyle='--', color='r',label='accuracy')
pyplot.xlabel('Step')
pyplot.title('Evaluation')
pyplot.legend()
pyplot.show()
